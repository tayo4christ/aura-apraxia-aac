# %% [markdown]
# # AURA Prototype Exploration
# Notebook for testing modules and data pipelines.

# %%
# Example: Load a .wav file
from utils.data_loader import load_audio_file
waveform, sr = load_audio_file("../sample.wav")
print(waveform.shape, sr)
